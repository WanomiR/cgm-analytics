# %%
from src.components.utils import *

# %%
entries = read_json("../data/entries.json")
entries
# Out:
#                             _id  noise                   sysTime    device  \
# 0      1670830457083e714d391d71    1.0  2022-12-12T07:34:17.000Z  DEXCOM52
# 1      1670829857504d574c2e41ad    1.0  2022-12-12T07:24:17.000Z  DEXCOM52
# 2      16708289569215b8b9471a93    1.0  2022-12-12T07:09:16.000Z  DEXCOM52
# 3      1670829555675af8d53dbbc6    1.0  2022-12-12T07:19:15.000Z  DEXCOM52
# 4      1670828657589b6156405dda    1.0  2022-12-12T07:04:17.000Z  DEXCOM52
# ...                         ...    ...                       ...       ...
# 13459  1675051678766f58ba6c3a1b    1.0  2023-01-30T04:07:58.000Z  DEXCOM52
# 13460  1675051978899410615f78b4    1.0  2023-01-30T04:12:58.000Z  DEXCOM52
# 13461  16750522802148a05e89b179    1.0  2023-01-30T04:18:00.000Z  DEXCOM52
# 13462  16750525801888c388906857    1.0  2023-01-30T04:23:00.000Z  DEXCOM52
# 13463  16750528810752a82b26cc52    1.0  2023-01-30T04:28:01.000Z  DEXCOM52
#
# ...

# %%
treatments = read_json("../data/treatments.json")
treatments
# Out:
#                                        _id  amount  rate  \
# 0     {'$oid': '6396db3aabbfb1132e1c40d6'}    0.15  2.35
# 1     {'$oid': '6396db3aabbfb1132e1c40d8'}    0.10  1.70
# 2     {'$oid': '6396db3aabbfb1132e1c40da'}    0.05  1.00
# 3     {'$oid': '6396db3aabbfb1132e1c40dc'}    0.05  0.80
# 4     {'$oid': '6396db3aabbfb1132e1c40de'}    0.00  0.45
# ...                                    ...     ...   ...
# 8637  {'$oid': '63d739a2abbfb1132e5b0d40'}    0.10  1.45
# 8638  {'$oid': '63d73bbaabbfb1132e5b0f41'}     NaN  0.00
# 8639  {'$oid': '63d73bcaabbfb1132e5b0f5b'}    0.00  0.00
# 8640  {'$oid': '63d73bccabbfb1132e5b0f60'}    0.00  0.00
# 8641  {'$oid': '63d7416aabbfb1132e5b14b5'}    0.00  0.00
#
#                  timestamp      enteredBy                created_at  \
# 0     2022-12-12T06:59:03Z  loop://iPhone  2022-12-12T06:59:03.000Z
# 1     2022-12-12T07:03:06Z  loop://iPhone  2022-12-12T07:03:06.000Z
# 2     2022-12-12T07:07:10Z  loop://iPhone  2022-12-12T07:07:10.000Z
# ...

# %%
tmp_basal = treatments[treatments["eventType"] == "Temp Basal"]
# Out:
#                                        _id  amount  rate  \
# 0     {'$oid': '6396db3aabbfb1132e1c40d6'}    0.15  2.35
# 1     {'$oid': '6396db3aabbfb1132e1c40d8'}    0.10  1.70
# 2     {'$oid': '6396db3aabbfb1132e1c40da'}    0.05  1.00
# 3     {'$oid': '6396db3aabbfb1132e1c40dc'}    0.05  0.80
# 4     {'$oid': '6396db3aabbfb1132e1c40de'}    0.00  0.45
# ...                                    ...     ...   ...
# 8637  {'$oid': '63d739a2abbfb1132e5b0d40'}    0.10  1.45
# 8638  {'$oid': '63d73bbaabbfb1132e5b0f41'}     NaN  0.00
# 8639  {'$oid': '63d73bcaabbfb1132e5b0f5b'}    0.00  0.00
# 8640  {'$oid': '63d73bccabbfb1132e5b0f60'}    0.00  0.00
# 8641  {'$oid': '63d7416aabbfb1132e5b14b5'}    0.00  0.00
#
#                  timestamp      enteredBy                created_at  \
# 0     2022-12-12T06:59:03Z  loop://iPhone  2022-12-12T06:59:03.000Z
# 1     2022-12-12T07:03:06Z  loop://iPhone  2022-12-12T07:03:06.000Z
# 2     2022-12-12T07:07:10Z  loop://iPhone  2022-12-12T07:07:10.000Z
# ...

# %%
read_json("../data/food.json")
# Out:
# Empty DataFrame
# Columns: []
# Index: []
